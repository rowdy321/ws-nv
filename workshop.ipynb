# %%
import math

# %%
print("pi is", math.pi)
# Out:
# pi is 3.141592653589793

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
# ...

# %%
from math import *
print('cos(pi) is', cos(pi))
# Out:
# cos(pi) is -1.0

# %%
import math as m
m.sin(m.pi)
# Out:
# 1.2246467991473532e-16

# %%
bases = 'ACTTGCTTGAC'
import random
number_of_bases=len(bases)
number_of_bases
# Out:
# 11

# %%
random_number=random.randrange(number_of_bases)
bases[random_number-1]
# Out:
# 'C'

# %%
random.choice(bases)
# Out:
# 'G'

# %%
log(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 log(0)
#
# ValueError: math domain error

# %% [markdown]
# **Panda as pd**

# %%
import pandas as pd

# %%
data=pd.read_csv('ws-nov\data\gapminder_all.csv')
data
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...

# %%
europe_data=pd.read_csv('ws-nov\data\gapminder_gdp_europe.csv')
europe_data
# Out:
#                    country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0                  Albania     1601.056136     1942.284244     2312.888958
# 1                  Austria     6137.076492     8842.598030    10750.721110
# 2                  Belgium     8343.105127     9714.960623    10991.206760
# 3   Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# 4                 Bulgaria     2444.286648     3008.670727     4254.337839
# 5                  Croatia     3119.236520     4338.231617     5477.890018
# 6           Czech Republic     6876.140250     8256.343918    10136.867130
# 7                  Denmark     9692.385245    11099.659350    13583.313510
# 8                  Finland     6424.519071     7545.415386     9371.842561
# 9                   France     7029.809327     8662.834898    10560.485530
# 10                 Germany     7144.114393    10187.826650    12902.462910
# ...

# %%
data=pd.read_csv('ws-nov\data\gapminder_gdp_oceania.csv', index_col='country')
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         2 non-null      object
#  1   gdpPercap_1952  2 non-null      float64
#  2   gdpPercap_1957  2 non-null      float64
#  3   gdpPercap_1962  2 non-null      float64
#  4   gdpPercap_1967  2 non-null      float64
#  5   gdpPercap_1972  2 non-null      float64
#  6   gdpPercap_1977  2 non-null      float64
#  7   gdpPercap_1982  2 non-null      float64
#  8   gdpPercap_1987  2 non-null      float64
#  9   gdpPercap_1992  2 non-null      float64
#  10  gdpPercap_1997  2 non-null      float64
#  11  gdpPercap_2002  2 non-null      float64
#  12  gdpPercap_2007  2 non-null      float64
# dtypes: float64(12), object(1)
# memory usage: 336.0+ bytes

# %%
europe_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         30 non-null     object
#  1   gdpPercap_1952  30 non-null     float64
#  2   gdpPercap_1957  30 non-null     float64
#  3   gdpPercap_1962  30 non-null     float64
#  4   gdpPercap_1967  30 non-null     float64
#  5   gdpPercap_1972  30 non-null     float64
#  6   gdpPercap_1977  30 non-null     float64
#  7   gdpPercap_1982  30 non-null     float64
#  8   gdpPercap_1987  30 non-null     float64
#  9   gdpPercap_1992  30 non-null     float64
#  10  gdpPercap_1997  30 non-null     float64
#  11  gdpPercap_2002  30 non-null     float64
#  12  gdpPercap_2007  30 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 3.2+ KB

# %%
data.columns
# Out:
# Index(['country', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007'],
#       dtype='object')

# %%
data.T
# Out:
#                           0            1
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686    13175.678
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751   16233.7177
# gdpPercap_1982  19477.00928   17632.4104
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
data.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
americas=pd.read_csv('ws-nov\data\gapminder_gdp_americas.csv', index_col='country')
americas.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
americas.head(3)
# Out:
#           continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina  Americas     5911.315053     6856.856212     7133.166023
# Bolivia    Americas     2677.326347     2127.686326     2180.972546
# Brazil     Americas     2108.944355     2487.365989     3336.585802
#
#            gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Argentina     8052.953021     9443.038526    10079.026740     8997.897412
# Bolivia       2586.886053     2980.331339     3548.097832     3156.510452
# Brazil        3429.864357     4985.711467     6660.118654     7030.835878
#
#            gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# country
# Argentina     9139.671389     9308.418710    10967.281950     8797.640716
# Bolivia       2753.691490     2961.699694     3326.143191     3413.262690
# Brazil        7807.095818     6950.283021     7957.980824     8131.212843
#
#            gdpPercap_2007
# country
# Argentina    12779.379640
# ...

# %%
americas.T.tail(5)
# Out:
# country           Argentina      Bolivia       Brazil       Canada  \
# gdpPercap_1987  9139.671389   2753.69149  7807.095818  26626.51503
# gdpPercap_1992   9308.41871  2961.699694  6950.283021  26342.88426
# gdpPercap_1997  10967.28195  3326.143191  7957.980824  28954.92589
# gdpPercap_2002  8797.640716   3413.26269  8131.212843  33328.96507
# gdpPercap_2007  12779.37964  3822.137084  9065.800825  36319.23501
#
# country               Chile     Colombia   Costa Rica         Cuba  \
# gdpPercap_1987  5547.063754    4903.2191  5629.915318  7532.924763
# gdpPercap_1992  7596.125964  5444.648617  6160.416317  5592.843963
# gdpPercap_1997  10118.05318  6117.361746  6677.045314  5431.990415
# gdpPercap_2002  10778.78385  5755.259962  7723.447195  6340.646683
# gdpPercap_2007  13171.63885  7006.580419   9645.06142  8948.102923
#
# country        Dominican Republic      Ecuador  ...       Mexico    Nicaragua  \
# ...

# %%
americas.to_csv('processed.csv')

# %%
data = pd.read_csv('ws-nov\data\gapminder_gdp_europe.csv', index_col='country')
print(data.iloc[0, 0])
# Out:
# 1601.056136

# %%
data.loc["Albania", "gdpPercap_1952"]
# Out:
# 1601.056136

# %%
data.loc["Albania", :]# the same as data.loc["Albania"]
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
data.loc[:, "gdpPercap_1952"]
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# ...

# %%
print(data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'])
print("-------------")
print(data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972'].min())
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993
# -------------
# gdpPercap_1962    4649.593785
# gdpPercap_1967    5907.850937
# gdpPercap_1972    7778.414017
# dtype: float64

# %%
# Use a subset of data to keep output readable.
subset = data.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
print('Subset of data:\n', subset)

# Which values were greater than 10000 ?
print('\nWhere are values large?\n', subset > 10000)
# Out:
# Subset of data:
#               gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993
#
# Where are values large?
#               gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                 False            True            True
# Montenegro            False           False           False
# Netherlands            True            True            True
# Norway                 True            True            True
# Poland                False           False           False

# %%
mask = subset > 10000
print(subset[mask])
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy                   NaN     10022.40131     12269.27378
# Montenegro              NaN             NaN             NaN
# Netherlands     12790.84956     15363.25136     18794.74567
# Norway          13450.40151     16361.87647     18965.05551
# Poland                  NaN             NaN             NaN

# %%
print(subset[subset > 10000].describe())
# Out:
#        gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# count        2.000000        3.000000        3.000000
# mean     13120.625535    13915.843047    16676.358320
# std        466.373656     3408.589070     3817.597015
# min      12790.849560    10022.401310    12269.273780
# 25%      12955.737548    12692.826335    15532.009725
# 50%      13120.625535    15363.251360    18794.745670
# 75%      13285.513522    15862.563915    18879.900590
# max      13450.401510    16361.876470    18965.055510

# %%
import matplotlib.pyplot as plt

# %%
time = [0,1,2,3]
position = [0,100,200,300]

plt.plot(time,position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# Text(0, 0.5, 'Position (km)')

# %%
data = pd.read_csv('ws-nov\data\gapminder_gdp_oceania.csv', index_col='country')
years = data.columns.str.strip('gdpPercap_')

# Convert year values to integers, saving results back to dataframe
data.columns = years.astype(int)
data.loc['Australia'].plot()
# Out:
# <AxesSubplot: >

# %%
data.T.plot()
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('GDP per capita')
# Out:
# Text(0, 0.5, 'GDP per capita')

# %%
pressures = [0.273, 0.275, 0.277, 0.275, 0.276]
print('pressures:', pressures)
print('length:', len(pressures))
pressures[0] = 0.265
print('pressures is now:', pressures)
# Out:
# pressures: [0.273, 0.275, 0.277, 0.275, 0.276]
# length: 5
# pressures is now: [0.265, 0.275, 0.277, 0.275, 0.276]

# %%
del pressures[3:9]
pressures
# Out:
# [0.277, 0.275, 0.276]

# %%
new_pressures = []

# %%
for number in [2, 3, 5]:
    print(number)
# Out:
# 2
# 3
# 5

# %%
original = "tin"
result = ""
for char in original:
    result = char + result
print(result)
# Out:
# nit

# %%
import glob
import pandas as pd
for filename in glob.glob('ws-nov\data\*.csv'):
    contents = pd.read_csv(filename)
    if len(contents) < 50:
        print(filename, len(contents))
# Out:
# ws-nov\data\gapminder_gdp_americas.csv 25
# ws-nov\data\gapminder_gdp_asia.csv 33
# ws-nov\data\gapminder_gdp_europe.csv 30
# ws-nov\data\gapminder_gdp_oceania.csv 2

# %%
for filename in glob.glob('ws-nov\data\*.csv'):
    contents = pd.read_csv(filename)
    print(contents)
# Out:
#     continent         country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0      Africa         Algeria     2449.008185     3013.976023     2550.816880
# 1      Africa          Angola     3520.610273     3827.940465     4269.276742
# 2      Africa           Benin     1062.752200      959.601080      949.499064
# 3      Africa        Botswana      851.241141      918.232535      983.653976
# 4      Africa    Burkina Faso      543.255241      617.183465      722.512021
# ..        ...             ...             ...             ...             ...
# 137    Europe     Switzerland    14734.232750    17909.489730    20431.092700
# 138    Europe          Turkey     1969.100980     2218.754257     2322.869908
# 139    Europe  United Kingdom     9979.508487    11283.177950    12477.177070
# 140   Oceania       Australia    10039.595640    10949.649590    12217.226860
# 141   Oceania     New Zealand    10556.575660    12247.395320    13175.678000
#
# ...
